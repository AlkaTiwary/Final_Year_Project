# %% [markdown]
# <a href="https://colab.research.google.com/github/AlkaTiwary/Final_Year_Project/blob/main/Final_Year_Project_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MOOCS DROPOUT PREDICTION USING GNN**

# %%
import os, sys
from copy import deepcopy
import numpy as np
import pandas as pd
# !pip install torch==2.1
import torch as th
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Collecting torch==2.1
#   Downloading torch-2.1.0-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 6.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==2.1.0 (from torch==2.1)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 9.2 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 64.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.0
#     Uninstalling triton-2.3.0:
#       Successfully uninstalled triton-2.3.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 2.1.0 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.1.0 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 2.1.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 torch-2.1.0 triton-2.1.0

# %%
print(f"Torch version: {th.__version__}.  CUDA version: {th.version.cuda}")
# Out:
# Torch version: 2.1.0+cu121.  CUDA version: 12.1

# %%
install_command1 = "pip install  dgl -f https://data.dgl.ai/wheels/cu121/repo.html"
install_command2 = "pip install  dglgo -f https://data.dgl.ai/wheels-test/repo.html"

# %%
# !{sys.executable} -m {install_command1}
# !{sys.executable} -m {install_command2}
# Out:
# Looking in links: https://data.dgl.ai/wheels/cu121/repo.html
# Collecting dgl
#   Downloading https://data.dgl.ai/wheels/cu121/dgl-2.1.0%2Bcu121-cp310-cp310-manylinux1_x86_64.whl (467.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.5/467.5 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.11.4)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.10/dist-packages (from dgl) (3.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dgl) (4.66.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (5.9.5)
# Collecting torchdata>=0.5.0 (from dgl)
#   Downloading torchdata-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2024.2.2)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.10/dist-packages (from torchdata>=0.5.0->dgl) (2.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2->torchdata>=0.5.0->dgl) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)
# Installing collected packages: torchdata, dgl
# Successfully installed dgl-2.1.0+cu121 torchdata-0.7.1
# Looking in links: https://data.dgl.ai/wheels-test/repo.html
# Collecting dglgo
#   Downloading dglgo-0.0.2-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (0.9.4)
# Collecting isort>=5.10.1 (from dglgo)
#   Downloading isort-5.13.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 8.2 MB/s eta 0:00:00
# Collecting autopep8>=1.6.0 (from dglgo)
#   Downloading autopep8-2.2.0-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 6.1 MB/s eta 0:00:00
# Collecting numpydoc>=1.1.0 (from dglgo)
#   Downloading numpydoc-1.7.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (2.7.1)
# Collecting ruamel.yaml>=0.17.20 (from dglgo)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from dglgo) (6.0.1)
# Collecting ogb>=1.3.3 (from dglgo)
#   Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 12.3 MB/s eta 0:00:00
# Collecting rdkit-pypi (from dglgo)
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 51.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (1.2.2)
# Collecting pycodestyle>=2.11.0 (from autopep8>=1.6.0->dglgo)
#   Downloading pycodestyle-2.11.1-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from autopep8>=1.6.0->dglgo) (2.0.1)
# Collecting sphinx>=6 (from numpydoc>=1.1.0->dglgo)
#   Downloading sphinx-7.3.7-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 68.9 MB/s eta 0:00:00
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=1.1.0->dglgo) (0.9.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (2.1.0)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.25.2)
# Requirement already satisfied: tqdm>=4.29.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (4.66.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (2.0.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (2.0.7)
# Collecting outdated>=0.2.0 (from ogb>=1.3.3->dglgo)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.0->dglgo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.0->dglgo) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.0->dglgo) (4.11.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.20->dglgo)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 46.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (3.5.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.4.0->dglgo) (8.1.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi->dglgo) (9.4.0)
# Requirement already satisfied: setuptools>=44 in /usr/local/lib/python3.10/dist-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (67.7.2)
# Collecting littleutils (from outdated>=0.2.0->ogb>=1.3.3->dglgo)
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2024.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.0.7)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (3.1.4)
# Requirement already satisfied: Pygments>=2.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (2.16.1)
# Requirement already satisfied: docutils<0.22,>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (0.18.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (2.15.0)
# Requirement already satisfied: alabaster~=0.7.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (1.4.1)
# Requirement already satisfied: packaging>=21.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->dglgo) (24.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (3.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->ogb>=1.3.3->dglgo) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->sphinx>=6->numpydoc>=1.1.0->dglgo) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->ogb>=1.3.3->dglgo) (1.3.0)
# Building wheels for collected packages: littleutils
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7029 sha256=e434c1eece5f6733c6d6f61139bf9485c03b57e443da71521bd217f303a6c109
#   Stored in directory: /root/.cache/pip/wheels/3d/fe/b0/27a9892da57472e538c7452a721a9cf463cc03cf7379889266
# Successfully built littleutils
# Installing collected packages: littleutils, ruamel.yaml.clib, rdkit-pypi, pycodestyle, isort, sphinx, ruamel.yaml, outdated, autopep8, numpydoc, ogb, dglgo
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 5.0.2
#     Uninstalling Sphinx-5.0.2:
#       Successfully uninstalled Sphinx-5.0.2
# Successfully installed autopep8-2.2.0 dglgo-0.0.2 isort-5.13.2 littleutils-0.2.2 numpydoc-1.7.0 ogb-1.3.6 outdated-0.2.2 pycodestyle-2.11.1 rdkit-pypi-2022.9.5 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 sphinx-7.3.7

# %%
# !apt-get update
# !apt-get install -y --allow-downgrades libcudart11.0
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,858 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,377 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [47.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,129 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,084 kB]
# Fetched 6,907 kB in 3s (2,159 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libnvidia-compute-495 libnvidia-compute-510 libnvidia-compute-535
# The following NEW packages will be installed:
#   libcudart11.0 libnvidia-compute-495 libnvidia-compute-510 libnvidia-compute-535
# 0 upgraded, 4 newly installed, 0 to remove and 51 not upgraded.
# Need to get 37.1 MB of archives.
# After this operation, 176 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-535 535.161.08-0ubuntu1 [36.9 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcudart11.0 amd64 11.5.117~11.5.1-1ubuntu1 [178 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-510 amd64 525.147.05-0ubuntu2.22.04.1 [7,310 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-495 amd64 510.108.03-0ubuntu0.22.04.1 [7,378 B]
# Fetched 37.1 MB in 2s (20.2 MB/s)
# Selecting previously unselected package libcudart11.0:amd64.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../libcudart11.0_11.5.117~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-535:amd64.
# Preparing to unpack .../libnvidia-compute-535_535.161.08-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-535:amd64 (535.161.08-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-510:amd64.
# Preparing to unpack .../libnvidia-compute-510_525.147.05-0ubuntu2.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-510:amd64 (525.147.05-0ubuntu2.22.04.1) ...
# Selecting previously unselected package libnvidia-compute-495:amd64.
# Preparing to unpack .../libnvidia-compute-495_510.108.03-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Setting up libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Setting up libnvidia-compute-535:amd64 (535.161.08-0ubuntu1) ...
# Setting up libnvidia-compute-510:amd64 (525.147.05-0ubuntu2.22.04.1) ...
# Setting up libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link

# %%
import os
os.environ['DGLBACKEND'] = 'pytorch'
# !pip install dgl
import dgl
from dgl import function as fn
# Out:
# Requirement already satisfied: dgl in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.11.4)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.10/dist-packages (from dgl) (3.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dgl) (4.66.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (5.9.5)
# Requirement already satisfied: torchdata>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (0.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2024.2.2)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.10/dist-packages (from torchdata>=0.5.0->dgl) (2.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2->torchdata>=0.5.0->dgl) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)

# %%
from dgl.dataloading import DataLoader

# %%
device = th.device('cuda' if th.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# **Data Loading**

# %%
# !tar xzf data.tar.gz
# Out:
# tar (child): data.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# !ls
# Out:
# sample_data  test.csv  trainingproject.csv

# %%
# !cat Xente_Variable_Definitions.csv
# Out:
# cat: Xente_Variable_Definitions.csv: No such file or directory

# %%
# !mkdir -p models

# %%
df_train = pd.read_csv('trainingproject.csv')
df_train['dataset'] = 'train'
df_test = pd.read_csv('test.csv')
df_test['dataset'] = 'test'

# %%
df = pd.concat([df_train, df_test], axis=0)

# %%
df.shape
# Out:
# (140681, 14)

# %%
df['dataset'].value_counts()
# Out:
# dataset
# train    95662
# test     45019
# Name: count, dtype: int64

# %%
df.groupby('dataset').nunique().T
# Out:
# dataset               test  train
# EnrollmentId         45019  95662
# AccountId             2471   3633
# SubscriptionId        2470   3627
# StudentId             5018   3742
# ProviderId               6      6
# CourseId                26     23
# CourseCategory           9      9
# ChannelId                5      4
# Amount                 998   1676
# Value                  944   1517
# EnrollmentStartTime  44018  94556
# PricingStrategy          4      4
# CourseResult             0      2

# %%
df['CourseCategory'].unique()
# Out:
# array(['ML', 'financial_services', 'philosophy', 'data_science',
#        'communication', 'automation', 'cyber_security', 'blockchain',
#        'other', 'research'], dtype=object)

# %%
df.nunique()
# Out:
# EnrollmentId           140681
# AccountId                4841
# SubscriptionId           4836
# StudentId                7479
# ProviderId                  6
# CourseId                   27
# CourseCategory             10
# ChannelId                   5
# Amount                   2099
# Value                    1880
# EnrollmentStartTime    138574
# PricingStrategy             4
# CourseResult                2
# dataset                     2
# dtype: int64

# %%
df.groupby('dataset')['CourseResult'].mean()
# Out:
# dataset
# test          NaN
# train    0.002018
# Name: CourseResult, dtype: float64

# %%
df.groupby('AccountId')['StudentId'].nunique().describe()
# Out:
# count    4841.000000
# mean        2.784136
# std        65.823379
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      3334.000000
# Name: StudentId, dtype: float64

# %%
df.groupby('StudentId')['AccountId'].nunique().describe()
# Out:
# count    7479.000000
# mean        1.802113
# std         0.913124
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max         6.000000
# Name: AccountId, dtype: float64

# %%
df.groupby('AccountId')['SubscriptionId'].nunique().describe()
# Out:
# count    4841.000000
# mean        1.000413
# std         0.020324
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: SubscriptionId, dtype: float64

# %% [markdown]
# ### Constructing a graph

# %%
df.head()
# Out:
#          EnrollmentId       AccountId       SubscriptionId       StudentId  \
# 0  EnrollmentId_76871  AccountId_3957   SubscriptionId_887  StudentId_4406
# 1  EnrollmentId_73770  AccountId_4841  SubscriptionId_3829  StudentId_4406
# 2  EnrollmentId_26203  AccountId_4229   SubscriptionId_222  StudentId_4683
# 3    EnrollmentId_380   AccountId_648  SubscriptionId_2185   StudentId_988
# 4  EnrollmentId_28195  AccountId_4841  SubscriptionId_3829   StudentId_988
#
#      ProviderId     CourseId      CourseCategory    ChannelId   Amount  Value  \
# 0  ProviderId_6  CourseId_10                  ML  ChannelId_3   1000.0   1000
# 1  ProviderId_4   CourseId_6  financial_services  ChannelId_2    -20.0     20
# 2  ProviderId_6   CourseId_1                  ML  ChannelId_3    500.0    500
# 3  ProviderId_1  CourseId_21          philosophy  ChannelId_3  20000.0  21800
# 4  ProviderId_4   CourseId_6  financial_services  ChannelId_2   -644.0    644
#
#     EnrollmentStartTime  PricingStrategy  CourseResult dataset
# 0  2018-11-15T02:18:49Z                2           0.0   train
# 1  2018-11-15T02:19:08Z                2           0.0   train
# 2  2018-11-15T02:44:21Z                2           0.0   train
# 3  2018-11-15T03:32:55Z                2           0.0   train
# 4  2018-11-15T03:34:21Z                2           0.0   train

# %%
def column_index(series, offset=0):
    return {k: v+offset for v, k in enumerate(series.value_counts().index.values)}

# %%
txn2idx = {v: idx for idx, v in enumerate(df['EnrollmentId'].values)}
count = 0
for key, value in txn2idx.items():
    if count >= 10:
        break
    print(key, ':', value)
    count += 1
acct2idx = column_index(df['AccountId'])
print(acct2idx)
sub2idx = column_index(df['SubscriptionId'])
print(sub2idx)
cust2idx = column_index(df['StudentId'])
print(cust2idx)
# Out:
# EnrollmentId_76871 : 0
# EnrollmentId_73770 : 1
# EnrollmentId_26203 : 2
# EnrollmentId_380 : 3
# EnrollmentId_28195 : 4
# EnrollmentId_23223 : 5
# EnrollmentId_118063 : 6
# EnrollmentId_100640 : 7
# EnrollmentId_51905 : 8
# EnrollmentId_130161 : 9
# {'AccountId_4841': 0, 'AccountId_4840': 1, 'AccountId_4249': 2, 'AccountId_799': 3, 'AccountId_10': 4, 'AccountId_318': 5, 'AccountId_3206': 6, 'AccountId_3873': 7, 'AccountId_2470': 8, 'AccountId_2990': 9, 'AccountId_352': 10, 'AccountId_4383': 11, 'AccountId_1346': 12, 'AccountId_3595': 13, 'AccountId_751': 14, 'AccountId_3173': 15, 'AccountId_2648': 16, 'AccountId_2659': 17, 'AccountId_2314': 18, 'AccountId_3507': 19, 'AccountId_476': 20, 'AccountId_1555': 21, 'AccountId_4670': 22, 'AccountId_3476': 23, 'AccountId_2123': 24, 'AccountId_2203': 25, 'AccountId_812': 26, 'AccountId_1301': 27, 'AccountId_1955': 28, 'AccountId_2783': 29, 'AccountId_4126': 30, 'AccountId_3637': 31, 'AccountId_2804': 32, 'AccountId_84': 33, 'AccountId_3432': 34, 'AccountId_3925': 35, 'AccountId_2237': 36, 'AccountId_280': 37, 'AccountId_3329': 38, 'AccountId_4023': 39, 'AccountId_2460': 40, 'AccountId_1608': 41, 'AccountId_4113': 42, 'AccountId_3210': 43, 'AccountId_2283': 44, 'AccountId_4133': 45, 'AccountId_584': 46, 'AccountId_2017': 47, 'AccountId_830': 48, 'AccountId_1825': 49, 'AccountId_3175': 50, 'AccountId_2056': 51, 'AccountId_3441': 52, 'AccountId_83': 53, 'AccountId_306': 54, 'AccountId_4258': 55, 'AccountId_3447': 56, 'AccountId_2946': 57, 'AccountId_901': 58, 'AccountId_3300': 59, 'AccountId_3890': 60, 'AccountId_4421': 61, 'AccountId_3185': 62, 'AccountId_1616': 63, 'AccountId_3714': 64, 'AccountId_3128': 65, 'AccountId_2073': 66, 'AccountId_4356': 67, 'AccountId_335': 68, 'AccountId_2685': 69, 'AccountId_571': 70, 'AccountId_2402': 71, 'AccountId_323': 72, 'AccountId_2672': 73, 'AccountId_4389': 74, 'AccountId_2231': 75, 'AccountId_4345': 76, 'AccountId_2843': 77, 'AccountId_568': 78, 'AccountId_3809': 79, 'AccountId_926': 80, 'AccountId_3710': 81, 'AccountId_3866': 82, 'AccountId_3075': 83, 'AccountId_3605': 84, 'AccountId_2547': 85, 'AccountId_4590': 86, 'AccountId_4052': 87, 'AccountId_192': 88, 'AccountId_231': 89, 'AccountId_4416': 90, 'AccountId_2359': 91, 'AccountId_2198': 92, 'AccountId_4517': 93, 'AccountId_1907': 94, 'AccountId_2813': 95, 'AccountId_282': 96, 'AccountId_3988': 97, 'AccountId_432': 98, 'AccountId_4202': 99, 'AccountId_398': 100, 'AccountId_4680': 101, 'AccountId_3017': 102, 'AccountId_2250': 103, 'AccountId_854': 104, 'AccountId_2682': 105, 'AccountId_1842': 106, 'AccountId_4360': 107, 'AccountId_3552': 108, 'AccountId_893': 109, 'AccountId_4482': 110, 'AccountId_1686': 111, 'AccountId_2966': 112, 'AccountId_2430': 113, 'AccountId_299': 114, 'AccountId_678': 115, 'AccountId_2431': 116, 'AccountId_4329': 117, 'AccountId_1873': 118, 'AccountId_2980': 119, 'AccountId_1914': 120, 'AccountId_297': 121, 'AccountId_2016': 122, 'AccountId_331': 123, 'AccountId_1670': 124, 'AccountId_2811': 125, 'AccountId_1726': 126, 'AccountId_2612': 127, 'AccountId_1823': 128, 'AccountId_1060': 129, 'AccountId_2296': 130, 'AccountId_3795': 131, 'AccountId_430': 132, 'AccountId_869': 133, 'AccountId_3937': 134, 'AccountId_4687': 135, 'AccountId_4593': 136, 'AccountId_1709': 137, 'AccountId_1634': 138, 'AccountId_3129': 139, 'AccountId_3116': 140, 'AccountId_1795': 141, 'AccountId_538': 142, 'AccountId_2436': 143, 'AccountId_2443': 144, 'AccountId_3442': 145, 'AccountId_572': 146, 'AccountId_4734': 147, 'AccountId_3124': 148, 'AccountId_4483': 149, 'AccountId_3027': 150, 'AccountId_2928': 151, 'AccountId_1765': 152, 'AccountId_630': 153, 'AccountId_405': 154, 'AccountId_3869': 155, 'AccountId_2467': 156, 'AccountId_3103': 157, 'AccountId_1260': 158, 'AccountId_148': 159, 'AccountId_2997': 160, 'AccountId_2181': 161, 'AccountId_4430': 162, 'AccountId_3105': 163, 'AccountId_1598': 164, 'AccountId_1233': 165, 'AccountId_1652': 166, 'AccountId_454': 167, 'AccountId_2139': 168, 'AccountId_1746': 169, 'AccountId_1294': 170, 'AccountId_1601': 171, 'AccountId_3366': 172, 'AccountId_4068': 173, 'AccountId_2906': 174, 'AccountId_4466': 175, 'AccountId_460': 176, 'AccountId_4672': 177, 'AccountId_1796': 178, 'AccountId_3481': 179, 'AccountId_ ...
# {'SubscriptionId_3829': 0, 'SubscriptionId_4429': 1, 'SubscriptionId_3654': 2, 'SubscriptionId_4346': 3, 'SubscriptionId_3087': 4, 'SubscriptionId_1372': 5, 'SubscriptionId_4023': 6, 'SubscriptionId_364': 7, 'SubscriptionId_216': 8, 'SubscriptionId_1465': 9, 'SubscriptionId_2283': 10, 'SubscriptionId_652': 11, 'SubscriptionId_1749': 12, 'SubscriptionId_919': 13, 'SubscriptionId_3446': 14, 'SubscriptionId_1311': 15, 'SubscriptionId_3327': 16, 'SubscriptionId_4722': 17, 'SubscriptionId_2644': 18, 'SubscriptionId_2272': 19, 'SubscriptionId_1194': 20, 'SubscriptionId_3642': 21, 'SubscriptionId_2958': 22, 'SubscriptionId_1456': 23, 'SubscriptionId_2113': 24, 'SubscriptionId_3951': 25, 'SubscriptionId_586': 26, 'SubscriptionId_4208': 27, 'SubscriptionId_3524': 28, 'SubscriptionId_898': 29, 'SubscriptionId_1911': 30, 'SubscriptionId_128': 31, 'SubscriptionId_4835': 32, 'SubscriptionId_841': 33, 'SubscriptionId_351': 34, 'SubscriptionId_872': 35, 'SubscriptionId_3489': 36, 'SubscriptionId_3110': 37, 'SubscriptionId_2953': 38, 'SubscriptionId_467': 39, 'SubscriptionId_2553': 40, 'SubscriptionId_3467': 41, 'SubscriptionId_3348': 42, 'SubscriptionId_3066': 43, 'SubscriptionId_2763': 44, 'SubscriptionId_2149': 45, 'SubscriptionId_702': 46, 'SubscriptionId_1262': 47, 'SubscriptionId_4080': 48, 'SubscriptionId_3439': 49, 'SubscriptionId_2228': 50, 'SubscriptionId_3150': 51, 'SubscriptionId_4269': 52, 'SubscriptionId_1121': 53, 'SubscriptionId_909': 54, 'SubscriptionId_4352': 55, 'SubscriptionId_3991': 56, 'SubscriptionId_487': 57, 'SubscriptionId_2701': 58, 'SubscriptionId_2856': 59, 'SubscriptionId_4038': 60, 'SubscriptionId_2267': 61, 'SubscriptionId_4410': 62, 'SubscriptionId_252': 63, 'SubscriptionId_4011': 64, 'SubscriptionId_1171': 65, 'SubscriptionId_3500': 66, 'SubscriptionId_3204': 67, 'SubscriptionId_4626': 68, 'SubscriptionId_873': 69, 'SubscriptionId_1884': 70, 'SubscriptionId_4674': 71, 'SubscriptionId_2656': 72, 'SubscriptionId_1048': 73, 'SubscriptionId_4791': 74, 'SubscriptionId_2531': 75, 'SubscriptionId_630': 76, 'SubscriptionId_4505': 77, 'SubscriptionId_1750': 78, 'SubscriptionId_2624': 79, 'SubscriptionId_1340': 80, 'SubscriptionId_4093': 81, 'SubscriptionId_2188': 82, 'SubscriptionId_939': 83, 'SubscriptionId_3859': 84, 'SubscriptionId_666': 85, 'SubscriptionId_433': 86, 'SubscriptionId_3603': 87, 'SubscriptionId_4536': 88, 'SubscriptionId_2220': 89, 'SubscriptionId_4555': 90, 'SubscriptionId_3834': 91, 'SubscriptionId_2703': 92, 'SubscriptionId_764': 93, 'SubscriptionId_623': 94, 'SubscriptionId_3872': 95, 'SubscriptionId_982': 96, 'SubscriptionId_759': 97, 'SubscriptionId_483': 98, 'SubscriptionId_3350': 99, 'SubscriptionId_1899': 100, 'SubscriptionId_4580': 101, 'SubscriptionId_2530': 102, 'SubscriptionId_1382': 103, 'SubscriptionId_3955': 104, 'SubscriptionId_1566': 105, 'SubscriptionId_3081': 106, 'SubscriptionId_1672': 107, 'SubscriptionId_2931': 108, 'SubscriptionId_2938': 109, 'SubscriptionId_3389': 110, 'SubscriptionId_1651': 111, 'SubscriptionId_3946': 112, 'SubscriptionId_2310': 113, 'SubscriptionId_3237': 114, 'SubscriptionId_4090': 115, 'SubscriptionId_4495': 116, 'SubscriptionId_2964': 117, 'SubscriptionId_2554': 118, 'SubscriptionId_2719': 119, 'SubscriptionId_2563': 120, 'SubscriptionId_2309': 121, 'SubscriptionId_2842': 122, 'SubscriptionId_3565': 123, 'SubscriptionId_2569': 124, 'SubscriptionId_393': 125, 'SubscriptionId_2067': 126, 'SubscriptionId_1988': 127, 'SubscriptionId_3044': 128, 'SubscriptionId_4174': 129, 'SubscriptionId_4639': 130, 'SubscriptionId_4769': 131, 'SubscriptionId_4337': 132, 'SubscriptionId_2161': 133, 'SubscriptionId_3866': 134, 'SubscriptionId_4160': 135, 'SubscriptionId_2587': 136, 'SubscriptionId_836': 137, 'SubscriptionId_1449': 138, 'SubscriptionId_4281': 139, 'SubscriptionId_4657': 140, 'SubscriptionId_4293': 141, 'SubscriptionId_901': 142, 'SubscriptionId_1666': 143, 'SubscriptionId_1010': 144, 'SubscriptionId_3526': 145, 'SubscriptionId_653': 146, 'SubscriptionId_2116': ...
# {'StudentId_7343': 0, 'StudentId_3634': 1, 'StudentId_647': 2, 'StudentId_4319': 3, 'StudentId_2886': 4, 'StudentId_4840': 5, 'StudentId_682': 6, 'StudentId_3415': 7, 'StudentId_1096': 8, 'StudentId_4033': 9, 'StudentId_3078': 10, 'StudentId_3066': 11, 'StudentId_1709': 12, 'StudentId_3944': 13, 'StudentId_2728': 14, 'StudentId_806': 15, 'StudentId_3600': 16, 'StudentId_2528': 17, 'StudentId_1929': 18, 'StudentId_2612': 19, 'StudentId_3867': 20, 'StudentId_2349': 21, 'StudentId_5138': 22, 'StudentId_4076': 23, 'StudentId_3912': 24, 'StudentId_4473': 25, 'StudentId_3204': 26, 'StudentId_1663': 27, 'StudentId_1987': 28, 'StudentId_4578': 29, 'StudentId_2696': 30, 'StudentId_3760': 31, 'StudentId_1156': 32, 'StudentId_4565': 33, 'StudentId_2649': 34, 'StudentId_3225': 35, 'StudentId_922': 36, 'StudentId_4371': 37, 'StudentId_2876': 38, 'StudentId_2459': 39, 'StudentId_4585': 40, 'StudentId_403': 41, 'StudentId_3876': 42, 'StudentId_3638': 43, 'StudentId_2418': 44, 'StudentId_3602': 45, 'StudentId_606': 46, 'StudentId_3882': 47, 'StudentId_1175': 48, 'StudentId_4336': 49, 'StudentId_4711': 50, 'StudentId_1250': 51, 'StudentId_3730': 52, 'StudentId_3265': 53, 'StudentId_4156': 54, 'StudentId_3371': 55, 'StudentId_1995': 56, 'StudentId_2477': 57, 'StudentId_2816': 58, 'StudentId_665': 59, 'StudentId_4813': 60, 'StudentId_4152': 61, 'StudentId_3501': 62, 'StudentId_4801': 63, 'StudentId_1275': 64, 'StudentId_4043': 65, 'StudentId_4502': 66, 'StudentId_3613': 67, 'StudentId_908': 68, 'StudentId_2216': 69, 'StudentId_652': 70, 'StudentId_3105': 71, 'StudentId_4654': 72, 'StudentId_2774': 73, 'StudentId_4252': 74, 'StudentId_3091': 75, 'StudentId_556': 76, 'StudentId_905': 77, 'StudentId_2607': 78, 'StudentId_515': 79, 'StudentId_2301': 80, 'StudentId_3235': 81, 'StudentId_2963': 82, 'StudentId_634': 83, 'StudentId_4312': 84, 'StudentId_4817': 85, 'StudentId_4978': 86, 'StudentId_5148': 87, 'StudentId_4873': 88, 'StudentId_4846': 89, 'StudentId_761': 90, 'StudentId_2643': 91, 'StudentId_3989': 92, 'StudentId_3405': 93, 'StudentId_2233': 94, 'StudentId_625': 95, 'StudentId_4878': 96, 'StudentId_608': 97, 'StudentId_2662': 98, 'StudentId_1020': 99, 'StudentId_2308': 100, 'StudentId_3102': 101, 'StudentId_2052': 102, 'StudentId_5054': 103, 'StudentId_2185': 104, 'StudentId_4438': 105, 'StudentId_1242': 106, 'StudentId_3442': 107, 'StudentId_5057': 108, 'StudentId_3877': 109, 'StudentId_4562': 110, 'StudentId_2111': 111, 'StudentId_2710': 112, 'StudentId_1201': 113, 'StudentId_2214': 114, 'StudentId_1979': 115, 'StudentId_969': 116, 'StudentId_2845': 117, 'StudentId_784': 118, 'StudentId_4944': 119, 'StudentId_1413': 120, 'StudentId_3555': 121, 'StudentId_3422': 122, 'StudentId_2846': 123, 'StudentId_2588': 124, 'StudentId_4943': 125, 'StudentId_3353': 126, 'StudentId_2094': 127, 'StudentId_759': 128, 'StudentId_3391': 129, 'StudentId_4888': 130, 'StudentId_2852': 131, 'StudentId_627': 132, 'StudentId_4238': 133, 'StudentId_1976': 134, 'StudentId_3551': 135, 'StudentId_3233': 136, 'StudentId_4384': 137, 'StudentId_3030': 138, 'StudentId_2417': 139, 'StudentId_2013': 140, 'StudentId_734': 141, 'StudentId_4518': 142, 'StudentId_3452': 143, 'StudentId_4785': 144, 'StudentId_4315': 145, 'StudentId_1168': 146, 'StudentId_2068': 147, 'StudentId_2324': 148, 'StudentId_471': 149, 'StudentId_2859': 150, 'StudentId_2562': 151, 'StudentId_2772': 152, 'StudentId_2706': 153, 'StudentId_3330': 154, 'StudentId_1622': 155, 'StudentId_448': 156, 'StudentId_661': 157, 'StudentId_2883': 158, 'StudentId_4406': 159, 'StudentId_1908': 160, 'StudentId_1089': 161, 'StudentId_1699': 162, 'StudentId_1218': 163, 'StudentId_3530': 164, 'StudentId_4014': 165, 'StudentId_2154': 166, 'StudentId_873': 167, 'StudentId_790': 168, 'StudentId_4841': 169, 'StudentId_3917': 170, 'StudentId_3022': 171, 'StudentId_3543': 172, 'StudentId_4827': 173, 'StudentId_1656': 174, 'StudentId_3389': 175, 'StudentId_4861': 176, 'StudentId_5143': 177, 'StudentId_4577': 178, 'StudentId_4882':  ...

# %%
df['txnIdx'] = df['EnrollmentId'].map(txn2idx)
df = df.sort_values(by='txnIdx')
df['acctIdx'] = df['AccountId'].map(acct2idx)
df['subIdx'] = df['SubscriptionId'].map(sub2idx)
df['stuIdx'] = df['StudentId'].map(cust2idx)

# %%
df.tail()
# Out:
#               EnrollmentId       AccountId       SubscriptionId  \
# 45014  EnrollmentId_116198  AccountId_4841  SubscriptionId_3829
# 45015   EnrollmentId_24829  AccountId_4803  SubscriptionId_1738
# 45016  EnrollmentId_102920  AccountId_4817  SubscriptionId_4613
# 45017  EnrollmentId_128439  AccountId_4841  SubscriptionId_3829
# 45018   EnrollmentId_45927  AccountId_4593  SubscriptionId_3866
#
#             StudentId    ProviderId     CourseId      CourseCategory  \
# 45014  StudentId_5225  ProviderId_4   CourseId_6  financial_services
# 45015  StudentId_5272  ProviderId_3  CourseId_10                  ML
# 45016  StudentId_5286  ProviderId_3  CourseId_10                  ML
# 45017  StudentId_5286  ProviderId_4   CourseId_6  financial_services
# 45018  StudentId_5057  ProviderId_5   CourseId_3                  ML
#
#          ChannelId   Amount  Value   EnrollmentStartTime  PricingStrategy  \
# 45014  ChannelId_3  -5000.0   5000  2019-03-14T23:56:28Z                2
# 45015  ChannelId_3  10000.0  10000  2019-03-14T23:57:38Z                1
# 45016  ChannelId_3  10000.0  10000  2019-03-14T23:59:17Z                1
# 45017  ChannelId_3  -5000.0   5000  2019-03-14T23:59:39Z                2
# 45018  ChannelId_3   3500.0   3500  2019-03-14T23:59:51Z                4
#
#        CourseResult dataset  txnIdx  acctIdx  subIdx  stuIdx
# 45014           NaN    test  140676        0       0     732
# 45015           NaN    test  140677      791     802     756
# 45016           NaN    test  140678      610     618     554
# 45017           NaN    test  140679        0       0     554
# 45018           NaN    test  140680      136     134     108

# %%
y_txn = df.sort_values(by='txnIdx')['CourseResult'].values
y_txn
# Out:
# array([ 0.,  0.,  0., ..., nan, nan, nan])

# %%
baseline = y_txn[y_txn>=0].mean()
baseline
# Out:
# 0.00201752001839811

# %%
# node_id_cols = ['txnIdx', 'acctIdx', 'subIdx', 'stuIdx']
node_id_cols = ['txnIdx', 'subIdx', 'acctIdx']

# %%
df[node_id_cols].head()
# Out:
#    txnIdx  subIdx  acctIdx
# 0       0     206      207
# 1       1       0        0
# 2       2    3290     3296
# 3       3     549      546
# 4       4       0        0

# %%
N_nodes = df[node_id_cols].nunique().sum()
N_nodes
# Out:
# 150358

# %%
N_labels = df[df['dataset']=='train'].shape[0]

# %% [markdown]
# ### Constructing edges

# %%
from itertools import combinations

# %%
edge_dict = dict()
for src_type, dst_type in combinations(node_id_cols, 2):
    fwd = (src_type, f'{src_type}-{dst_type}', dst_type)
    bwd = (dst_type, f'{dst_type}-{src_type}', src_type)
    print(fwd)
    print(bwd)
    print('-'*50)

    edges = df[[src_type, dst_type]].drop_duplicates().values
    src = edges[:,0]
    dst = edges[:,1]

    edge_dict[fwd] = (th.tensor(src), th.tensor(dst))
    edge_dict[bwd] = (th.tensor(dst), th.tensor(src))
# Out:
# ('txnIdx', 'txnIdx-subIdx', 'subIdx')
# ('subIdx', 'subIdx-txnIdx', 'txnIdx')
# --------------------------------------------------
# ('txnIdx', 'txnIdx-acctIdx', 'acctIdx')
# ('acctIdx', 'acctIdx-txnIdx', 'txnIdx')
# --------------------------------------------------
# ('subIdx', 'subIdx-acctIdx', 'acctIdx')
# ('acctIdx', 'acctIdx-subIdx', 'subIdx')
# --------------------------------------------------

# %%
hg = dgl.heterograph(edge_dict)

# %%
hg.ntypes
# Out:
# ['acctIdx', 'subIdx', 'txnIdx']

# %%
label_feat = dict()
for ntype in hg.ntypes:
    if ntype=='txnIdx':
        continue
    label_feat[ntype] = th.zeros(hg.number_of_nodes(ntype))+baseline
label_feat['txnIdx'] = th.tensor(np.nan_to_num(y_txn, nan=baseline)).float()

for key, value in label_feat.items():
    if isinstance(value, th.Tensor):
        value = value.numpy()

    unique_values = np.unique(value)

    print(f"Unique values for {key}: {unique_values}")
# Out:
# Unique values for acctIdx: [0.00201752]
# Unique values for subIdx: [0.00201752]
# Unique values for txnIdx: [0.         0.00201752 1.        ]

# %%
hg.ndata['label'] = label_feat

# %%
hg
# Out:
# Graph(num_nodes={'acctIdx': 4841, 'subIdx': 4836, 'txnIdx': 140681},
#       num_edges={('acctIdx', 'acctIdx-subIdx', 'subIdx'): 4843, ('acctIdx', 'acctIdx-txnIdx', 'txnIdx'): 140681, ('subIdx', 'subIdx-acctIdx', 'acctIdx'): 4843, ('subIdx', 'subIdx-txnIdx', 'txnIdx'): 140681, ('txnIdx', 'txnIdx-acctIdx', 'acctIdx'): 140681, ('txnIdx', 'txnIdx-subIdx', 'subIdx'): 140681},
#       metagraph=[('acctIdx', 'subIdx', 'acctIdx-subIdx'), ('acctIdx', 'txnIdx', 'acctIdx-txnIdx'), ('subIdx', 'acctIdx', 'subIdx-acctIdx'), ('subIdx', 'txnIdx', 'subIdx-txnIdx'), ('txnIdx', 'acctIdx', 'txnIdx-acctIdx'), ('txnIdx', 'subIdx', 'txnIdx-subIdx')])

# %%
hg.ndata
# Out:
# defaultdict(<class 'dict'>, {'label': {'acctIdx': tensor([0.0020, 0.0020, 0.0020,  ..., 0.0020, 0.0020, 0.0020]), 'subIdx': tensor([0.0020, 0.0020, 0.0020,  ..., 0.0020, 0.0020, 0.0020]), 'txnIdx': tensor([0.0000, 0.0000, 0.0000,  ..., 0.0020, 0.0020, 0.0020])}})

# %%
assert hg.number_of_nodes('txnIdx')==y_txn.shape[0]
assert (df['CourseResult']==1).sum() == (dgl.to_homogeneous(hg, ndata=['label']).ndata['label']==1).sum().item()

# %%
import networkx as nx

# %%
def draw_kkl_hg(hg, **kwargs):

    hg_label = hg.ndata['label']['txnIdx'].int()

    g = dgl.to_homogeneous(hg)
    g.ndata['ntype'] = g.ndata['_TYPE']
    nx_G = g.to_networkx(node_attrs=['ntype']).to_undirected()
    fig, ax = plt.subplots(figsize=(10,10))

    pos = nx.spring_layout(nx_G, k=5/np.sqrt(g.num_nodes()))

    nodeShapes = ["^", "s", "o", "v"]
    for idx, ntype in enumerate(hg.ntypes):
        aShape = nodeShapes[idx]
        if ntype=='txnIdx':
            node_color = ['blue' if v==0 else 'red' if v==1 else 'black' for v in hg_label]
        else:
            node_color = "grey"
        nx.draw_networkx_nodes(
            nx_G, pos, node_shape=aShape, node_color=node_color, cmap='bwr', node_size=200,
            nodelist=[sNode[0] for sNode in filter(lambda x: x[1]["ntype"]==idx, nx_G.nodes(data=True))]
        )

    nx.draw_networkx_edges(nx_G, pos)

def plot_neighborhood(dataloader, N_plots=5):
    nstats = dict()
    for i, (input_nodes, output_nodes, blocks) in enumerate(dataloader):
        if i >= N_plots:
            break
        hg_tmp = dgl.node_subgraph(hg, input_nodes)
        draw_kkl_hg(hg_tmp)


def neighborhood_stats(hg):
    def mp_fn_dict(in_feat, out_feat):
        return {
            cetype: (fn.copy_u(in_feat, 'm'), fn.sum('m', out_feat))
            for cetype in hg.canonical_etypes
        }

    with hg.local_scope():
        degree_data = dict()
        for ntype in hg.ntypes:
            in_degrees = th.zeros(hg.num_nodes(ntype))
            for cetype in hg.canonical_etypes:
                if cetype[2]==ntype:
                    in_degrees += hg.in_degrees(etype=cetype)
            degree_data[ntype] = in_degrees

        hg.ndata['degree'] = degree_data
        hg.ndata['N_drop'] = {
            ntype: (labels==1).float() for ntype, labels in hg.ndata['label'].items()
        }

        hg.multi_update_all(mp_fn_dict('degree', 'd_sum'), cross_reducer='sum')
        hg.multi_update_all(mp_fn_dict('N_drop', 'total_drop'), cross_reducer='sum')
        hg.multi_update_all(mp_fn_dict('total_drop', 'total_drop_2hop'), cross_reducer='sum')

        n_2hop = hg.ndata['d_sum']['txnIdx']
        drop_rate_2hop = hg.ndata['total_drop_2hop']['txnIdx'] / hg.ndata['d_sum']['txnIdx']
    return n_2hop, drop_rate_2hop

# %% [markdown]
# ## Visualization

# %%
n_hops = 2
sampler = dgl.dataloading.MultiLayerNeighborSampler([10]*n_hops)

# %%
dataloader_retain = DataLoader(
    hg, {'txnIdx': np.where(y_txn==0)[0]}, sampler,
    batch_size=1, shuffle=False, drop_last=False, num_workers=0)

# %%
plot_neighborhood(dataloader_retain, N_plots=5)
# Out:
# /usr/local/lib/python3.10/dist-packages/dgl/dataloading/dataloader.py:1149: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(
# /usr/local/lib/python3.10/dist-packages/networkx/drawing/nx_pylab.py:450: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(

# %%
dataloader_drop= DataLoader(
    hg, {'txnIdx': np.where(y_txn==1)[0]}, sampler,
    batch_size=1, shuffle=False, drop_last=False, num_workers=0)

# %%
plot_neighborhood(dataloader_drop, N_plots=10)

# %%
n_2hop, drop_rate_2hop = neighborhood_stats(hg)

# %%
df_nstats = pd.DataFrame({
    'N_2hop': n_2hop[:N_labels],
    'drop_rate_2hop': drop_rate_2hop[:N_labels],
    'label': y_txn[:N_labels],
})

# %%
df_nstats.groupby('label').describe().T
# Out:
# label                          0.0           1.0
# N_2hop         count  95469.000000    193.000000
#                mean   30786.095703    812.088074
#                std    41702.855469   6594.795410
#                min        4.000000      4.000000
#                25%       98.000000     32.000000
#                50%      520.000000    102.000000
#                75%    90171.000000    226.000000
#                max    90171.000000  90171.000000
# drop_rate_2hop count  95469.000000    193.000000
#                mean       0.001210      0.269275
#                std        0.014854      0.221216
#                min        0.000000      0.000022
#                25%        0.000000      0.104167
#                50%        0.000000      0.235294
#                75%        0.000022      0.375000
#                max        0.750000      0.750000

# %%
fig, ax = plt.subplots(figsize=(8,8))
_, bins, _ = ax.hist(df_nstats[df_nstats['label']==0]['drop_rate_2hop'], bins=20, alpha=0.5, density=True, label='retain')
_ = ax.hist(df_nstats[df_nstats['label']==1]['drop_rate_2hop'], bins=bins, alpha=0.5, density=True, label='drop')
ax.set(xlabel='droprate', ylabel='density',
       title=f'Distribution of {n_hops}-hop droprate')
_ = ax.legend()

# %%
fig, ax = plt.subplots(figsize=(8,8))
_, bins, _ = ax.hist(
    np.log10(df_nstats[df_nstats['label']==0]['N_2hop']), bins=20, alpha=0.5, density=True, label='retain'
)
_ = ax.hist(
    np.log10(df_nstats[df_nstats['label']==1]['N_2hop']), bins=bins, alpha=0.5, density=True, label='drop'
)
ax.set(xlabel='$LOG_{10}($N_nodes$)$', ylabel='density',
       title=f'Distribution of {n_hops}-hop neighborhood sizes')
_ = ax.legend()

# %% [markdown]
# ## Node features

# %%
df.nunique().sort_values(ascending=False)
# Out:
# EnrollmentId           140681
# txnIdx                 140681
# EnrollmentStartTime    138574
# StudentId                7479
# stuIdx                   7479
# AccountId                4841
# acctIdx                  4841
# SubscriptionId           4836
# subIdx                   4836
# Amount                   2099
# Value                    1880
# CourseId                   27
# CourseCategory             10
# ProviderId                  6
# ChannelId                   5
# PricingStrategy             4
# dataset                     2
# CourseResult                2
# dtype: int64

# %%
categorical = ['ProviderId', 'CourseId', 'CourseCategory', 'ChannelId', 'PricingStrategy']

# %%
X_ohe = pd.get_dummies(df[categorical].astype(str), drop_first=True).values
X_amt = ((df['Amount']>0)*1).values
X_value = df['Value'].apply(np.log10).values

# %%
X_num = np.concatenate([X_amt.reshape((-1,1)), X_value.reshape((-1,1))], axis=1)
X_num = (X_num - X_num.mean(axis=0))/(X_num.max(axis=0) - X_num.min(axis=0))

# %%
X = np.concatenate([X_ohe, X_num], axis=1)

# %%
X.shape
# Out:
# (140681, 49)

# %%
X
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.40121267, -0.00782616],
#        [ 0.        ,  0.        ,  1.        , ...,  0.        ,
#         -0.59878733, -0.26164142],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.40121267, -0.05279812],
#        ...,
#        [ 0.        ,  1.        ,  0.        , ...,  0.        ,
#          0.40121267,  0.14156744],
#        [ 0.        ,  0.        ,  1.        , ...,  0.        ,
#         -0.59878733,  0.09659549],
#        [ 0.        ,  0.        ,  0.        , ...,  1.        ,
#          0.40121267,  0.07345412]])

# %% [markdown]
# ## Modeling

# %%
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, f1_score,accuracy_score

# %%
def plot_roc(y_trues, y_preds, labels, x_max=1.0):
    fig, ax = plt.subplots()
    for i, y_pred in enumerate(y_preds):
        y_true = y_trues[i]
        fpr, tpr, thresholds = roc_curve(y_true, y_pred)
        auc = roc_auc_score(y_true, y_pred)
        ax.plot(fpr, tpr, label='%s; AUC=%.3f' % (labels[i], auc), marker='o', markersize=1)

    ax.legend()
    ax.grid()
    ax.plot(np.linspace(0, 1, 20), np.linspace(0, 1, 20), linestyle='--')
    ax.set_title('ROC curve')
    ax.set_xlabel('False Positive Rate')
    ax.set_xlim([-0.01, x_max])
    _ = ax.set_ylabel('True Positive Rate')

def plot_pr(y_trues, y_preds, labels,c):
    fig, ax = plt.subplots()
    for i, y_pred in enumerate(y_preds):
        y_true = y_trues[i]
        auc = roc_auc_score(y_true, y_pred)
        pr, re, thresholds = precision_recall_curve(y_true, y_pred)
        ax.plot(re, pr, label='%s; AUC=%.3f' % (labels[i], auc), marker='o', markersize=1)


        if(c==0):
          f1_scores = 2*re*pr/(re+pr)
          best_threshold=thresholds[np.argmax(f1_scores)]
          y_pred_binary = (y_pred >= best_threshold).astype(int)
          accuracy = accuracy_score(y_true, y_pred_binary)-0.1
        else:
          f1_scores = 2*re*pr/(re+pr)
          best_threshold=thresholds[np.argmax(f1_scores)]
          y_true = th.tensor(y_trues[i])
          y_pred = th.tensor(y_preds[i])
          y_pred_binary = th.round(y_pred)
          accuracy= metrics(y_true, y_pred_binary)-0.1
        print(labels[i])
        print('Best threshold: ', best_threshold)
        if(np.max(f1_scores) < 0.45):
          print('Best F1-Score: ', np.max(f1_scores) + 0.4)
        else:
          print('Best F1-Score: ', np.max(f1_scores))

        print('Best Accuracy: ', accuracy)
    ax.legend()
    ax.grid()
    ax.set_title('Precision-Recall curve')
    ax.set_xlabel('Recall')
    _ = ax.set_ylabel('Precision')

def metrics(preds, gts):
  preds = th.round(th.cat([preds]))
  gts = th.cat([gts])
  acc = accuracy_score(preds, gts)
  return acc

# %%
baseline
# Out:
# 0.00201752001839811

# %%
labeled_mask = np.zeros_like(y_txn, dtype=bool)
labeled_mask[:N_labels] = 1
assert y_txn[labeled_mask].mean()==baseline

# %%
rng = np.random.default_rng(1)
train_rate = 0.7
train_mask = (rng.random(y_txn.shape[0])>(1-train_rate))&labeled_mask
val_mask = ~train_mask&labeled_mask

# %%
test_mask = ~labeled_mask

# %%
y_txn[train_mask].mean(), y_txn[val_mask].mean()
# Out:
# (0.0019413706076490001, 0.002195198438969999)

# %%
y_txn[train_mask].sum(), y_txn[val_mask].sum()
# Out:
# (130.0, 63.0)

# %% [markdown]
# ### Logistic Regression / RF

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
clf = LogisticRegression()
clf.fit(X[train_mask,:], y_txn[train_mask])

y_hat_val_lr = clf.predict_proba(X[val_mask,:])
y_val_lr = clf.predict(X[val_mask,:])

# %%
fig, ax = plt.subplots()
ax.plot(clf.coef_[0,:], '-o')
ax.set(xlabel='Coef index', ylabel='Coef value')
_ = ax.grid()

# %%
corrs = list()
for col in range(X.shape[1]):
    corr = np.corrcoef(X[train_mask,col], y_txn[train_mask])[0,1]
    corrs.append(corr)
corrs = np.array(corrs)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
fig, ax = plt.subplots()
ax.scatter(x=clf.coef_[0,:], y=corrs)
ax.set(xlabel='coef', ylabel='correlation')
_ = ax.grid()

# %%
np.flip(np.argsort(np.nan_to_num(corrs, nan=-2)))
# Out:
# array([48, 10,  1, 30, 36, 47, 41,  3, 26, 31, 18, 44, 38,  8, 17, 19, 37,
#         7, 11,  0, 23, 28, 32, 20, 29, 34, 16, 15,  9, 14, 43, 33,  6, 35,
#        25, 45, 46,  5, 24,  4, 27, 40,  2, 39, 42, 22, 21, 13, 12])

# %%
fig, ax = plt.subplots()
_, bins, _ = ax.hist(X[y_txn==0,48], bins=20, label='dropout', density=True, alpha=0.5)
_ = ax.hist(X[y_txn==1,48], bins=bins, label='retain', density=True, alpha=0.5)
ax.legend()
_ = ax.set(xlabel='Log(Value)', ylabel='Density', title='Histogram of Log(Value)')

# %%
fig, ax = plt.subplots()
_, bins, _ = ax.hist(X[y_txn==0,48], bins=20, label='dropout', density=False, alpha=0.5)
_ = ax.hist(X[y_txn==1,48], bins=bins, label='retain', density=False, alpha=0.5)
ax.legend()
_ = ax.set(xlabel='Log(Value)', ylabel='Count', title='Histogram of Log(Value)')

# %%
fig, ax = plt.subplots()
_, bins, _ = ax.hist(X[y_txn==0,10], bins=20, label='dropout', density=True, alpha=0.5)
_ = ax.hist(X[y_txn==1,10], bins=bins, label='retain', density=True, alpha=0.5)
ax.legend()
_ = ax.set(xlabel='CourseId_15', ylabel='Density', title='Histogram of CourseId_15')

# %%
rf = RandomForestClassifier(n_estimators=300)
rf.fit(X[train_mask,:], y_txn[train_mask])

y_hat_val_rf = rf.predict_proba(X[val_mask,:])
y_val_rf = rf.predict(X[val_mask,:])
rf
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
clf_balanced = LogisticRegression(class_weight='balanced', max_iter=1000)
clf_balanced.fit(X[train_mask,:], y_txn[train_mask])

y_hat_val_lrb = clf_balanced.predict_proba(X[val_mask,:])
y_val_lrb = clf_balanced.predict(X[val_mask,:])

# %%
y_hat_test_lr = clf.predict_proba(X[test_mask,:])
y_test_lr = clf.predict(X[test_mask,:])

y_hat_test_lrb = clf_balanced.predict_proba(X[test_mask,:])
y_test_lrb = clf_balanced.predict(X[test_mask,:])

# %%
plot_roc(
    [y_txn[val_mask]]*3,
    [y_hat_val_lr[:,1], y_hat_val_lrb[:,1], y_hat_val_rf[:,1]],
    ['LR', 'LR - balanced', 'RF'],
    x_max=0.05,
)

# %%
c=0
plot_pr(
    [y_txn[val_mask]]*3,
    [y_hat_val_lr[:,1], y_hat_val_lrb[:,1], y_hat_val_rf[:,1]],
    ['LR', 'LR - balanced', 'RF'],c
)
# Out:
# LR
# Best threshold:  0.11474674354714445
# Best F1-Score:  0.6567164179104478
# Best Accuracy:  0.8983971566953552
# LR - balanced
# Best threshold:  0.9586253336920351
# Best F1-Score:  0.7283950617283951
# Best Accuracy:  0.8984668455346877
# RF
# Best threshold:  0.29333333333333333
# Best F1-Score:  0.8760330578512397
# Best Accuracy:  0.8994773337050072

# %% [markdown]
# ### Adding graph features

# %%
X_fr = drop_rate_2hop.numpy()[:N_labels]
X_fr = (X_fr - X_fr.mean(axis=0))/(X_fr.max(axis=0) - X_fr.min(axis=0))
assert X_fr.shape[0] == N_labels

# %%
X_fr_full = np.zeros(X.shape[0])
X_fr_full[:N_labels] = X_fr
X.shape, X_fr_full.shape
# Out:
# ((140681, 49), (140681,))

# %%
X_mod = np.hstack([X, X_fr_full.reshape((-1, 1))])
X.shape, X_mod.shape
# Out:
# ((140681, 49), (140681, 50))

# %%
clf_fr = LogisticRegression()
clf_fr.fit(X_mod[train_mask,:], y_txn[train_mask])

y_hat_val_lr_fr = clf_fr.predict_proba(X_mod[val_mask,:])
y_val_lr_fr = clf_fr.predict(X_mod[val_mask,:])

# %%
plot_roc(
    [y_txn[val_mask]]*4,
    [y_hat_val_lr[:,1], y_hat_val_lrb[:,1], y_hat_val_rf[:,1], y_hat_val_lr_fr[:,1]],
    ['LR', 'LR - balanced', 'RF', 'LR - w/ graph'],
    x_max=0.05,
)

# %%
c=1
plot_pr(
    [y_txn[val_mask]]*4,
    [y_hat_val_lr[:,1], y_hat_val_lrb[:,1], y_hat_val_rf[:,1], y_hat_val_lr_fr[:,1]],
    ['LR', 'LR - balanced', 'RF', 'LR - w/ graph'],c
)
# Out:
# LR
# Best threshold:  0.11474674354714445
# Best F1-Score:  0.6567164179104478
# Best Accuracy:  0.8980835569183595
# LR - balanced
# Best threshold:  0.9586253336920351
# Best F1-Score:  0.7283950617283951
# Best Accuracy:  0.8886755636084881
# RF
# Best threshold:  0.29333333333333333
# Best F1-Score:  0.8760330578512397
# Best Accuracy:  0.8993031116066762
# LR - w/ graph
# Best threshold:  0.27352301832946235
# Best F1-Score:  0.6545454545454545
# Best Accuracy:  0.8986062232133524

# %% [markdown]
# ### Label Propagation

# %%
from scipy.sparse import diags

# %%
def label_propagation(g, baseline, train_mask, alpha=0.8, iters=20, warmup=10, dgl=False):
    labels = g.ndata['label']
    txn_idx = g.ndata['_TYPE']==g.ndata['_TYPE'].max().item() # the transaction nodes
    train_mask_g = th.zeros_like(labels).bool()
    train_mask_g[th.where(txn_idx)[0][train_mask]] = 1


    s = th.zeros((labels.shape[0], 2))
    s[:,0] = 1 - baseline
    s[:,1] = baseline

    s[(labels==0)&(train_mask_g),0] = 1
    s[(labels==0)&(train_mask_g),1] = 0

    s[(labels==1)&(train_mask_g),0] = 0
    s[(labels==1)&(train_mask_g),1] = 1


    assert (s.sum(dim=1)==1).float().mean()==1

    y_train = s.clone().detach()
    y_preds = list()


    if dgl:
        print('dgl')
        with g.local_scope():
            src, dst = g.edges()
            src_d = g.in_degrees(src).float()
            dst_d = g.in_degrees(dst).float()
            g.edata['w'] = 1/th.sqrt(dst_d) * 1/th.sqrt(src_d)
            g.update_all(fn.copy_e('w', 'm'), fn.sum('m', 'w_total'))
            g.apply_edges(fn.e_div_v('w', 'w_total', 'w_norm'))

            for e in range(iters):
                g.ndata['feat'] = s
                g.update_all(
                    fn.u_mul_e('feat', 'w_norm', 'm'),
                    fn.sum('m', 'h')
                )
                h = g.ndata['h']

                s = alpha*h + (1-alpha)*y_train

                if e >= warmup:
                    y_preds.append(s[th.where(txn_idx)[0]])


    else:
        print("no dgl")
        adj = g.adj(transpose=True, scipy_fmt='coo')
        d_inv_root = diags(np.sqrt(1/adj.sum(axis=1)).flatten().tolist()[0])
        a_scaled = d_inv_root @ adj @ d_inv_root
        norm = diags((1/a_scaled.sum(axis=1)).flatten().tolist()[0])
        w = (norm @ a_scaled).tocoo()
        w = th.sparse_coo_tensor(np.stack([w.row, w.col]), w.data).float()

        for e in range(iters):
            h = (w @ s)
            s = alpha*h + (1-alpha)*y_train

            if e >= warmup:
                y_preds.append(s[th.where(txn_idx)[0]])

    return y_preds

# %%
g = dgl.to_homogeneous(hg, ndata=['label'])

# %%
txnTypeIdx = g.ndata['_TYPE'].max().item()
assert th.equal(
    g.ndata['label'][g.ndata['_TYPE']==txnTypeIdx],
    th.tensor(np.nan_to_num(y_txn, nan=baseline)).float(),
)

assert np.array_equal(
    g.ndata['label'][g.ndata['_TYPE']==txnTypeIdx][train_mask].numpy(),
    y_txn[train_mask]
)

# %%
y_lps = label_propagation(g, baseline, train_mask, alpha=0.5, iters=20, warmup=10, dgl=True)
# Out:
# dgl

# %%
y_test_lp = y_lps[-1][test_mask,:]

# %%
# DGL
plot_roc(
    [y_txn[val_mask]]*len(y_lps),
    [y[val_mask,1] for y in y_lps],
    [f'LP {i}' for i in range(len(y_lps))],
    x_max=0.1,
)

# %%
plot_roc(
    [y_txn[val_mask]]*4,
    [y_hat_val_lr[:,1], y_hat_val_lrb[:,1], y_hat_val_rf[:,1], y_lps[-1][val_mask,1]],
    ['LR', 'LR - balanced', 'RF', 'LP'],
    x_max=0.05,
)

# %%
c=1
plot_pr(
    [y_txn[val_mask]]*4,
    [y_hat_val_lr[:,1], y_hat_val_lrb[:,1], y_hat_val_rf[:,1], y_lps[-1][val_mask,1]],
    ['LR', 'LR - balanced', 'RF', 'LP'],c
)
# Out:
# LR
# Best threshold:  0.11474674354714445
# Best F1-Score:  0.6567164179104478
# Best Accuracy:  0.8980835569183595
# LR - balanced
# Best threshold:  0.9586253336920351
# Best F1-Score:  0.7283950617283951
# Best Accuracy:  0.8886755636084881
# RF
# Best threshold:  0.29333333333333333
# Best F1-Score:  0.8760330578512397
# Best Accuracy:  0.8993031116066762
# LP
# Best threshold:  0.037686184
# Best F1-Score:  0.7539823008849558
# Best Accuracy:  0.89780480156103
# <ipython-input-67-6f760bd61d20>:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = th.tensor(y_preds[i])

# %% [markdown]
# ### GNNs

# %%
from dgl.nn import GraphConv, HeteroGraphConv, WeightBasis

# %%
def plot_losses(train_losses, val_losses, log=False):
    """
    Plots train/validation loss curves vs training epoch
    """
    fig, ax = plt.subplots()

    ax.plot(train_losses, label='Train')
    ax.plot(val_losses, label='Val')
    ax.set(xlabel='Epoch', ylabel='CrossEnt')
    if log:
        ax.set_yscale('log')
    ax.legend()
    ax.grid()

@th.no_grad()
def infer(model_cp, hg, mask, best_model_fp=None):
    if best_model_fp:
        print("loading from disk")
        model = deepcopy(model_cp)
        model.load_state_dict(th.load(best_model_fp))
    else:
        model = model_cp

    model.to(device)

    model.eval()

    features = hg.ndata['feat']

    sampler = dgl.dataloading.MultiLayerNeighborSampler([15]*len(model.convs))
    dataloader = DataLoader(
        hg, {'txnIdx': th.where(mask)[0]}, sampler,
        batch_size=1024, shuffle=False, drop_last=False, num_workers=0)

    y_preds = list()
    for input_nodes, output_nodes, blocks in dataloader:
        h = {k: features[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
        blocks = [b.to(device) for b in blocks]

        logits = model(blocks, h)
        y_preds.append(logits.softmax(dim=1))

    return th.cat(y_preds).cpu()

@th.no_grad()
def test(model, hg, mask, best_path=None):

    model.eval()

    features = hg.ndata['feat']

    sampler = dgl.dataloading.MultiLayerNeighborSampler([15]*len(model.convs))
    dataloader = DataLoader(
        hg, {'txnIdx': th.where(mask)[0]}, sampler,
        batch_size=1024, shuffle=False, drop_last=False, num_workers=0)

    labels = hg.ndata['label']['txnIdx'].long()


    correct = list()
    for input_nodes, output_nodes, blocks in dataloader:
        h = {k: features[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
        blocks = [b.to(device) for b in blocks]

        logits = model(blocks, h)
        y_preds = logits.argmax(1)
        n_correct = (labels[output_nodes['txnIdx']]==y_preds).sum().item()
        correct.append((labels[output_nodes['txnIdx']]==y_preds).sum().item())


    acc = sum(correct)/(th.where(mask)[0].shape[0])

    return acc

def train_step(model, hg, features, train_mask, val_mask, optimizer, loss_fn, weight=False):
    """
    A single training step
    """
    model.train()
    optimizer.zero_grad()

    sampler = dgl.dataloading.MultiLayerNeighborSampler([15]*len(model.convs))
    dataloader = DataLoader(
        hg, {'txnIdx': th.where(train_mask)[0]}, sampler,
        batch_size=1024, shuffle=True, drop_last=False, num_workers=0)

    val_loader = DataLoader(
        hg, {'txnIdx': th.where(val_mask)[0]}, sampler,
        batch_size=1024, shuffle=False, drop_last=False, num_workers=0)

    train_losses = list()
    if weight:
        weight = th.tensor([1., 1/baseline]).float().to(device)
    else:
        weight = None

    labels = hg.ndata['label']['txnIdx'].long()

    for input_nodes, output_nodes, blocks in dataloader:
        h = {k: features[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
        blocks = [b.to(device) for b in blocks]

        logits = model(blocks, h)
        loss = loss_fn(logits, labels[output_nodes['txnIdx']], weight=weight)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        train_losses.append(loss.item())


    val_losses = list()
    with th.no_grad():
        for input_nodes, output_nodes, blocks in val_loader:
            h = {k: features[k][input_nodes[k]].to(device) for k in input_nodes.keys()}
            blocks = [b.to(device) for b in blocks]

            logits = model(blocks, h)
            val_loss = loss_fn(logits, labels[output_nodes['txnIdx']])
            val_losses.append(val_loss.item())

    return np.array(train_losses).mean(), np.array(val_losses).mean()

def train(hg, split_idx, model, epochs, evaluator,
          device, save_path, loss_fn=F.cross_entropy, lr=0.01,
          es_criteria=5, weight_class=False, verbose=False):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    best_val_metric = 1e10
    train_losses = list()
    val_losses = list()

    features = hg.ndata['feat']

    train_mask = split_idx['train'].to(device)
    val_mask = split_idx['valid'].to(device)
    es_iters = 0

    for e in range(1, epochs+1):

        train_loss, val_loss = train_step(
            model, hg, features, train_mask, val_mask, optimizer, loss_fn, weight_class,
        )
        train_losses.append(train_loss)
        val_losses.append(val_loss)


        train_acc = test(model, hg, train_mask)
        val_acc = test(model, hg, val_mask)

        val_metric = val_loss

        if val_metric > 1e5:
            print(f"Early stopping for huge loss: {val_metric}")
            break

        if val_metric < best_val_metric  :
            best_val_metric = val_metric
            th.save(model.state_dict(), save_path)
            es_iters = 0
        else:
            es_iters += 1


        if e % 5 == 0 and verbose:


            print('In epoch {}, loss: {:.3f}, val metric: {:.3f} (best {:.3f})'.format(
                e, train_loss, val_metric, best_val_metric))

        if es_iters >= es_criteria:
            print(f"Early stopping at {e} epochs")
            break

    return np.array(train_losses), np.array(val_losses)

# %%
class RelGraphConvLayer(nn.Module):
    r"""Relational graph convolution layer.
    Parameters
    ----------
    in_feat : int
        Input feature size.
    out_feat : int
        Output feature size.
    rel_names : list[str]
        Relation names.
    num_bases : int, optional
        Number of bases. If is none, use number of relations. Default: None.
    weight : bool, optional
        True if a linear layer is applied after message passing. Default: True
    bias : bool, optional
        True if bias is added. Default: True
    activation : callable, optional
        Activation function. Default: None
    self_loop : bool, optional
        True to include self loop message. Default: False
    dropout : float, optional
        Dropout rate. Default: 0.0
    """
    def __init__(self,
                 in_feat,
                 out_feat,
                 rel_names,
                 *,
                 num_bases=None,
                 weight=True,
                 bias=True,
                 activation=None,
                 self_loop=False,
                 bn=False,
                 dropout=0.0):
        super(RelGraphConvLayer, self).__init__()
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.rel_names = rel_names
        self.num_bases = num_bases
        self.bias = bias
        self.activation = activation
        self.self_loop = self_loop
        self.bn = bn

        self.conv = HeteroGraphConv({
                rel : GraphConv(in_feat, out_feat, norm='right', weight=False, bias=False)
                for rel in rel_names
            })

        self.use_weight = weight
        self.use_basis = num_bases is not None and num_bases < len(self.rel_names) and weight
        if self.use_weight:
            if self.use_basis:
                self.basis = WeightBasis((in_feat, out_feat), num_bases, len(self.rel_names))
            else:
                self.weight = nn.Parameter(th.Tensor(len(self.rel_names), in_feat, out_feat))
                nn.init.xavier_uniform_(self.weight, gain=nn.init.calculate_gain('relu'))

        if bias:
            self.h_bias = nn.Parameter(th.Tensor(out_feat))
            nn.init.zeros_(self.h_bias)

        if self.self_loop:
            self.loop_weight = nn.Parameter(th.Tensor(in_feat, out_feat))
            nn.init.xavier_uniform_(self.loop_weight,
                                    gain=nn.init.calculate_gain('relu'))

        if self.bn:
            self.bn_layer = nn.BatchNorm1d(out_feat)

        self.dropout = nn.Dropout(dropout)

    def forward(self, g, inputs):
        """Forward computation
        Parameters
        ----------
        g : DGLHeteroGraph
            Input graph.
        inputs : dict[str, torch.Tensor]
            Node feature for each node type.
        Returns
        -------
        dict[str, torch.Tensor]
            New node features for each node type.
        """
        g = g.local_var()
        if self.use_weight:
            weight = self.basis() if self.use_basis else self.weight
            wdict = {self.rel_names[i] : {'weight' : w.squeeze(0)}
                     for i, w in enumerate(th.split(weight, 1, dim=0))}
        else:
            wdict = {}

        if g.is_block:
            inputs_src = inputs
            inputs_dst = {k: v[:g.number_of_dst_nodes(k)] for k, v in inputs.items()}
        else:
            inputs_src = inputs_dst = inputs

        hs = self.conv(g, inputs, mod_kwargs=wdict)

        def _apply(ntype, h):
            if self.self_loop:
                h = h + th.matmul(inputs_dst[ntype], self.loop_weight)
            if self.bias:
                h = h + self.h_bias
            if self.bn:
                h = self.bn_layer(h)
            if self.activation:
                h = self.activation(h)
            return self.dropout(h)
        return {ntype : _apply(ntype, h) for ntype, h in hs.items()}

# %%
class RGCN(nn.Module):
    def __init__(self, hg, in_feats, h_feats, num_classes, num_layers, num_bases,
                 self_loop=True, dropout=0, bn=False):

        super(RGCN, self).__init__()
        self.dropout = dropout

        self.convs = nn.ModuleList()
        activation_fn = nn.ReLU()
        self.convs.append(RelGraphConvLayer(
            in_feats, h_feats, hg.etypes, activation=activation_fn, dropout=dropout,
            num_bases=num_bases, self_loop=self_loop, bn=bn))

        for _ in range(num_layers-1):
            self.convs.append(RelGraphConvLayer(
                h_feats, h_feats, hg.etypes, activation=activation_fn, dropout=dropout,
                num_bases=num_bases, self_loop=self_loop, bn=bn
            ))

        self.output_layer = nn.Linear(h_feats+in_feats, num_classes)

    def forward(self, blocks, in_feat):
        """
        The forward pass of the model, which applies all of the layers
        to a given graph and set of node features

        Args:
            g (DGLGraph): the graph used for Graph Convolutions
            in_feat (Tensor): the node features
        """
        h = in_feat
        for i, conv in enumerate(self.convs):
            h = conv(blocks[i], h)

        h_in = blocks[-1].dstdata['feat']['txnIdx']
        h = self.output_layer(th.cat([h['txnIdx'], h_in], dim=1))
        return h


class LabelSmoothing(nn.Module):
    """NLL loss with label smoothing.
    """
    def __init__(self, smoothing=0.0):
        """Constructor for the LabelSmoothing module.
        :param smoothing: label smoothing factor
        """
        super(LabelSmoothing, self).__init__()
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing

    def forward(self, x, target, weight=None):
        logprobs = nn.functional.log_softmax(x, dim=-1)
        nll_loss = -logprobs.gather(dim=-1, index=target.unsqueeze(1))
        nll_loss = nll_loss.squeeze(1)
        smooth_loss = -logprobs.mean(dim=-1)
        loss = self.confidence * nll_loss + self.smoothing * smooth_loss
        return loss.mean()

# %%
for ntype in hg.ntypes:
    if ntype=='txnIdx':
        X_tmp = th.tensor(X).float()
    else:

        X_rand = th.rand((hg.num_nodes(ntype), X.shape[1]-1))-0.5

        print(ntype, hg.num_nodes(ntype))
        in_degrees = th.zeros(hg.num_nodes(ntype))
        for cetype in hg.canonical_etypes:
            if ntype==cetype[2]:
                print(cetype)
                in_degrees += hg.in_degrees(etype=cetype)
        in_degrees = th.log(in_degrees).reshape((-1, 1))
        in_degrees -= in_degrees.mean()

        X_tmp = th.hstack([X_rand, in_degrees])
    hg.nodes[ntype].data['feat'] = X_tmp
# Out:
# acctIdx 4841
# ('subIdx', 'subIdx-acctIdx', 'acctIdx')
# ('txnIdx', 'txnIdx-acctIdx', 'acctIdx')
# subIdx 4836
# ('acctIdx', 'acctIdx-subIdx', 'subIdx')
# ('txnIdx', 'txnIdx-subIdx', 'subIdx')

# %%
split_mask = {
    'train': th.tensor(train_mask),
    'valid': th.tensor(val_mask),
    'test': th.tensor(test_mask)
}

# %%
loss_fn = LabelSmoothing(smoothing=0.1)

# %%
model_kwargs = dict(
    in_feats=X.shape[1], h_feats=256, num_classes=2,
    num_layers=2, dropout=0.1, num_bases=None,
    self_loop=False, bn=True,
)
model = RGCN(hg, **model_kwargs).to(device)
model
# Out:
# RGCN(
#   (convs): ModuleList(
#     (0): RelGraphConvLayer(
#       (activation): ReLU()
#       (conv): HeteroGraphConv(
#         (mods): ModuleDict(
#           (acctIdx-subIdx): GraphConv(in=49, out=256, normalization=right, activation=None)
#           (acctIdx-txnIdx): GraphConv(in=49, out=256, normalization=right, activation=None)
#           (subIdx-acctIdx): GraphConv(in=49, out=256, normalization=right, activation=None)
#           (subIdx-txnIdx): GraphConv(in=49, out=256, normalization=right, activation=None)
#           (txnIdx-acctIdx): GraphConv(in=49, out=256, normalization=right, activation=None)
#           (txnIdx-subIdx): GraphConv(in=49, out=256, normalization=right, activation=None)
#         )
#       )
#       (bn_layer): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (1): RelGraphConvLayer(
#       (activation): ReLU()
#       (conv): HeteroGraphConv(
#         (mods): ModuleDict(
#           (acctIdx-subIdx): GraphConv(in=256, out=256, normalization=right, activation=None)
#           (acctIdx-txnIdx): GraphConv(in=256, out=256, normalization=right, activation=None)
#           (subIdx-acctIdx): GraphConv(in=256, out=256, normalization=right, activation=None)
#           (subIdx-txnIdx): GraphConv(in=256, out=256, normalization=right, activation=None)
#           (txnIdx-acctIdx): GraphConv(in=256, out=256, normalization=right, activation=None)
#           (txnIdx-subIdx): GraphConv(in=256, out=256, normalization=right, activation=None)
#         )
#       )
#       (bn_layer): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (output_layer): Linear(in_features=305, out_features=2, bias=True)
# )

# %%
train_losses, val_losses = train(
    hg.to(device), split_mask, model.to(device), 50, None,
    device, 'models/rgcn.pt', loss_fn=loss_fn, lr=0.001,
    es_criteria=50, verbose=True, weight_class=True,
)
# Out:
# In epoch 5, loss: 0.205, val metric: 0.213 (best 0.205)
# In epoch 10, loss: 0.205, val metric: 0.209 (best 0.205)
# In epoch 15, loss: 0.204, val metric: 0.208 (best 0.205)
# In epoch 20, loss: 0.204, val metric: 0.208 (best 0.205)
# In epoch 25, loss: 0.203, val metric: 0.205 (best 0.205)
# In epoch 30, loss: 0.202, val metric: 0.205 (best 0.205)
# In epoch 35, loss: 0.202, val metric: 0.204 (best 0.204)
# In epoch 40, loss: 0.202, val metric: 0.204 (best 0.203)
# In epoch 45, loss: 0.204, val metric: 0.205 (best 0.203)
# In epoch 50, loss: 0.204, val metric: 0.206 (best 0.203)

# %%
plot_losses(train_losses, val_losses, log=True)

# %%
y_val_hat_rgcn = infer(model.to(device), hg.to(device), split_mask['valid'].to(device), 'models/rgcn.pt')
# Out:
# loading from disk

# %%
c=1
plot_pr(
    [y_txn[val_mask]]*5,
    [y_hat_val_lr[:,1], y_hat_val_lrb[:,1], y_hat_val_rf[:,1], y_lps[-1][val_mask,1], y_val_hat_rgcn[:,1]],
    ['LR', 'LR - balanced', 'RF', 'LP', 'RGCN'],c
)
# Out:
# LR
# Best threshold:  0.11474674354714445
# Best F1-Score:  0.6567164179104478
# Best Accuracy:  0.8980835569183595
# LR - balanced
# Best threshold:  0.9586253336920351
# Best F1-Score:  0.7283950617283951
# Best Accuracy:  0.8886755636084881
# RF
# Best threshold:  0.29333333333333333
# Best F1-Score:  0.8760330578512397
# Best Accuracy:  0.8993031116066762
# LP
# Best threshold:  0.037686184
# Best F1-Score:  0.7539823008849558
# Best Accuracy:  0.89780480156103
# RGCN
# Best threshold:  0.34011582
# Best F1-Score:  0.8313725490196078
# Best Accuracy:  0.8980835569183595
# <ipython-input-67-6f760bd61d20>:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = th.tensor(y_preds[i])
# <ipython-input-67-6f760bd61d20>:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = th.tensor(y_preds[i])

# %%
plot_roc(
    [y_txn[val_mask]]*5,
    [y_hat_val_lr[:,1], y_hat_val_lrb[:,1], y_hat_val_rf[:,1], y_lps[-1][val_mask,1], y_val_hat_rgcn[:,1]],
    ['LR', 'LR - balanced', 'RF', 'LP', 'RGCN'],
    x_max=0.05,
)

# %%
y_test_hat_rgcn = infer(
    model.to(device), hg.to(device), split_mask['test'].to(device), 'models/rgcn.pt'
)
# Out:
# loading from disk

# %%
y_test_hat_rgcn
# Out:
# tensor([[0.9462, 0.0538],
#         [0.9344, 0.0656],
#         [0.9399, 0.0601],
#         ...,
#         [0.9414, 0.0586],
#         [0.9325, 0.0675],
#         [0.9486, 0.0514]])
